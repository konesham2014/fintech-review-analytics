# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/raw/bank_reviews_cleaned.csv")

print(df.head())

# %%
df2 = pd.read_csv("data/raw/task2_output.csv")

print(df2["sentiment_label"].value_counts())
print(df2["identified_theme"].value_counts())

# %%
df2["sentiment_label"].value_counts().plot(kind="bar")

plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")

plt.show()
